# %%
 # IMPORT LIBRARIES
import pandas as pd
import numpy as np
import os.path
import datetime
import scipy as sp
import pytz 

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib
import itertools
import importlib as imp
from cvxpy import *
from sklearn.metrics import mean_squared_error
from math import sqrt

#import Modules.SolarDisaggregation as sd #disaggregateSolar, createTempInput,disaggregateSolarIndividualSparse,
#import Modules.PecanTempMod as ptm
#import Modules.EpiDataSolarMod as epd
from copy import * 
# %matplotlib inline

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e21bb3bb-4762-4a5b-8565-9f32595fdd08">Loading BokehJS ...</span>
#     </div>

# %%
import sqlalchemy as sq
engine = sq.create_engine("postgresql+psycopg2://7gi6wEsghEgO:mnMRXtOPVvkX@dataport.pecanstreet.org:5434/postgres")

# %%
the_frame = pd.read_sql_query('SELECT table_schema,table_name FROM information_schema.tables ORDER BY table_schema,table_name;', engine)
the_frame
# Out:
#            table_schema                           table_name
# 0                caliso                      demand_forecast
# 1                caliso                         interval_lmp
# 2                caliso                        sys_load_rsrc
# 3                caliso                          ws_forecast
# 4       electricity_sec                       egauge_1s_2014
# 5       electricity_sec                       egauge_1s_2015
# 6       electricity_sec                       egauge_1s_2016
# 7       electricity_sec                       egauge_1s_2017
# 8                 ercot            actual_load_xweather_zone
# 9                 ercot             ancillary_service_offers
# 10                ercot                              dam_spp
# 11                ercot                      hdl_ldl_summary
# 12                ercot            hourly_realtime_vs_actual
# 13                ercot      hourly_resource_outage_capacity
# 14                ercot  hourly_ruc_transmission_constraints
# 15                ercot                    knowledge_reports
# 16                ercot    load_forecast_xforecast_zone_7day
# 17                ercot     load_forecast_xweather_zone_7day
# 18                ercot                    peaker_net_margin
# 19                ercot                         realtime_lmp
# 20                ercot                         realtime_spp
# 21                ercot                    solar_actual_5min
# 22                ercot     solar_hourly_actual_and_forecast
# 23                ercot               solar_pwr_pot_forecast
# 24                ercot                                swcap
# 25                ercot                   system_wide_demand
# 26                ercot                     wind_actual_5min
# 27                ercot      wind_hourly_actual_and_forecast
# 28                ercot                   wind_output_hourly
# 29   information_schema    administrable_role_authorizations
# ..                  ...                                  ...
# 188                 pjm                 ancillary_svc_lmp_hr
# 189                 pjm                     day_ahead_lmp_hr
# 190                 pjm                     real_time_lmp_hr
# 191                 pjm        verified_ancillary_svc_lmp_hr
# 192                 pjm                      verified_lmp_hr
# 193              public                   pg_stat_statements
# 194          university                          audits_2011
# 195          university               audits_2013_appliances
# 196          university        audits_2013_duct_leakage_eval
# 197          university                     audits_2013_main
# 198          university                 civita_text_messages
# 199          university            egauge_detailed_registers
# 200          university             electricity_egauge_15min
# 201          university             electricity_egauge_hours
# 202          university           electricity_egauge_minutes
# 203          university                    electric_vehicles
# 204          university                              gas_ert
# 205          university            indoor_temperature_sensor
# 206          university                       pricing_events
# 207          university         pricing_events_notifications
# 208          university         survey_2011_all_participants
# 209          university         survey_2012_all_participants
# 210          university       survey_2012_field_descriptions
# 211          university         survey_2013_all_participants
# 212          university       survey_2013_field_descriptions
# 213          university         survey_2014_all_participants
# 214          university       survey_2014_field_descriptions
# 215          university                       water_capstone
# 216          university                            water_ert
# 217          university                              weather
#
# [218 rows x 2 columns]

# %%
 # import psycopg2
query="""SELECT dataid, localhour, use, gen, air1, air2, air3, airwindowunit1, furnace1, furnace2 FROM university.electricity_egauge_hours
WHERE localhour
BETWEEN '01-01-2016' AND '01-1-2017' AND dataid in (22,    59,  77,     86
) """


# query="""SELECT *
# FROM university.electricity_egauge_hours
# LIMIT 10 """

egauge = pd.read_sql_query(query,engine)
egauge.shape
# Out:
# (26355, 10)

# %%
# Out:
#         localhour   use   gen  air1  air2  air3  airwindowunit1  furnace1  \
# dataid
# 26           8785  8785  8785  8785     0     0               0      8785
# 59           8785  8785     0  8785     0     0               0      8785
# 77           8785  8785  8785  8785     0     0               0      8785
# 86           8785  8785     0  8785     0     0               0      8785
#
#         furnace2
# dataid
# 26             0
# 59             0
# 77             0
# 86             0

# %%
 # import psycopg2
the_frame = pd.read_sql_query('SELECT table_schema,table_name FROM information_schema.tables ORDER BY table_schema,table_name;', engine)
the_frame[the_frame['table_schema'].str.contains('university')]
#query gets everything for the week
query="""SELECT dataid, local_15min, use, gen, air1, air2, air3, airwindowunit1, furnace1, furnace2 electricity_egauge_15min FROM university.electricity_egauge_15min
WHERE local_15min
BETWEEN '01-01-2015' AND '01-21-2015' AND electricity_egauge_15min.dataid in (22, 114) """

query="""SELECT distinct(dataid) FROM university.electricity_egauge_hours
"""


# query="""SELECT *
# FROM university.electricity_egauge_hours
# LIMIT 10 """

dataids = pd.read_sql_query(query,engine)
dataids
# Out:
#      dataid
# 0      3368
# 1      4874
# 2      6800
# 3      9585
# 4      3401
# 5      7989
# 6      1350
# 7      6334
# 8      5652
# 9      4776
# 10     4438
# 11     1167
# 12     4193
# 13     6673
# 14     7680
# 15     7893
# 16     8829
# 17     2510
# 18   100240
# 19     8086
# 20     9195
# 21     3519
# 22     9922
# 23   100186
# 24     3795
# 25   100160
# 26     8574
# 27     4313
# 28     4927
# 29     5403
# ..      ...
# 798    7769
# 799  100216
# 800    4544
# 801    3299
# 802    1589
# 803    5485
# 804    9165
# 805    3935
# 806    8956
# 807  100082
# 808     130
# 809    7793
# 810  100084
# 811    4773
# 812     772
# 813    4000
# 814    3719
# 815    7208
# 816    9277
# 817    7013
# 818    3538
# 819    7703
# 820    1791
# 821    1331
# 822    6139
# 823    1801
# 824    2824
# 825    7408
# 826    1185
# 827    6268
#
# [828 rows x 1 columns]

# %%
np.sort(dataids['dataid'])
# Out:
# array([    22,     26,     48,     54,     59,     68,     77,     86,
#            93,     94,    101,    114,    115,    121,    130,    135,
#           160,    171,    187,    203,    222,    232,    243,    252,
#           267,    275,    280,    297,    330,    347,    364,    370,
#           379,    410,    434,    436,    457,    470,    483,    484,
#           490,    491,    499,    503,    507,    508,    516,    527,
#           545,    547,    555,    573,    575,    580,    585,    604,
#           621,    624,    645,    661,    668,    698,    739,    744,
#           765,    772,    774,    781,    796,    821,    861,    871,
#           878,    890,    898,    900,    930,    936,    946,    954,
#           974,    980,    991,    994,   1037,   1069,   1086,   1103,
#          1105,   1153,   1167,   1169,   1185,   1192,   1202,   1283,
#          1310,   1314,   1331,   1334,   1350,   1354,   1392,   1403,
#          1415,   1450,   1463,   1464,   1479,   1500,   1507,   1508,
#          6692,   6730,   6799,   6800,   6826,   6836,   6871,   6887,
#          6888,   6910,   6911,   6941,   6956,   6960,   6979,   6990,
#          7001,   7013,   7016,   7017,   7024,   7030,   7036,   7057,
#          7062,   7108,   7114,   7117,   7122,   7166,   7208,   7240,
#          7276,   7287,   7319,   7361,   7390,   7408,   7409,   7429,
#          7436,   7468,   7491,   7504,   7510,   7512,   7527,   7531,
#          7536,   7541,   7549,   7560,   7585,   7587,   7597,   7617,
#          7627,   7638,   7639,   7641,   7680,   7693,   7703,   7719,
#          7731,   7739,   7741,   7764,   7767,   7769,   7787,   7788,
#          7792,   7793,   7794,   7800,   7818,   7850,   7863,   7866,
#          7875,   7881,   7893,   7900,   7901,   7940,   7951,   7965,
#          7973,   7982,   7984,   7989,   8029,   8031,   8034,   8046,
#          8047,   8059,   8061,   8071,   8079,   8084,   8086,   8092,
#          8117,   8121,   8122,   8142,   8155,   8156,   8163,   8183,
#          8188,   8197,   8198,   8201,   8218,   8236,   8243,   8273,
#          8282,   8292,   8317,   8328,   8342,   8368,   8386,   8395,
#          8419,   8467,   8555,   8565,   8574,   8589,   8597,   8600,
#          8622,   8626,   8645,   8669,   8729,   8730,   8733,   8736,
#          8741,   8767,   8807,   8829,   8847,   8848,   8852,   8857,
#          8862,   8872,   8886,   8890,   8942,   8956,   8961,   8967,
#          8986,   8995,   9001,   9019,   9036,   9052,   9085,   9121,
#          9134,   9139,   9141,   9142,   9156,   9160,   9165,   9182,
#          9195,   9201,   9206,   9213,   9215,   9233,   9235,   9237,
#          9248,   9251,   9277,   9278,   9295,   9333,   9340,   9341,
#          9343,   9356,   9370,   9434,   9451,   9462,   9484,   9488,
#          9498,   9499,   9509,   9548,   9555,   9578,   9585,   9605,
#          9609,   9610,   9612,   9613,   9624,   9631,   9642,   9643,
#          9647,   9654,   9670,   9674,   9688,   9701,   9729,   9737,
#          9745,   9766,   9771,   9773,   9775,   9776,   9803,   9818,
#          9830,   9836,   9846,   9875,   9912,   9915,   9919,   9921,
#          9922,   9923,   9926,   9929,   9931,   9932,   9933,   9934,
#          9935,   9936,   9937,   9938,   9939,   9942,   9958,   9971,
#          9981,   9982,   9983, 100055, 100056, 100059, 100062, 100063,
#        100064, 100065, 100066, 100069, 100082, 100084, 100085, 100087,
#        100088, 100089, 100091, 100092, 100094, 100097, 100099, 100101,
#        100102, 100103, 100106, 100107, 100108, 100109, 100111, 100113,
#        100115, 100116, 100118, 100121, 100135, 100142, 100153, 100160,
#        100167, 100168, 100175, 100177, 100178, 100179, 100183, 100186,
#        100188, 100189, 100207, 100211, 100212, 100213, 100214, 100215,
#        100216, 100218, 100219, 100220, 100221, 100224, 100225, 100226,
#        100230, 100232, 100235, 100236, 100237, 100238, 100240, 100241,
#        100243, 100244, 100245, 100248, 100251, 100252, 100253, 100254,
#        100255, 100256, 100257, 100267])

# %%
query = """SELECT * FROM university.weather WHERE latitude = 40.027278 AND localhour 
BETWEEN '01-01-2016' AND '01-1-2017' """
#query = 'SELECT * FROM university.weather LIMIT 100'
the_frame = pd.read_sql_query(query,engine)
the_frame.shape
# Out:
# (8825, 28)
